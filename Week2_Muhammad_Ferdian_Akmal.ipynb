# %% [markdown]
# <a href="https://colab.research.google.com/github/Nathanblke/Nathanblke/blob/main/Week2_Muhammad_Ferdian_Akmal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from skimage import io
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import matplotlib.colors as colorsss
import random

gambarr = cv.imread('/content/drive/MyDrive/PendaftaranUM/FotoGlasses.jpg')
gambarr_4 = cv.cvtColor(gambarr,cv.COLOR_BGR2RGB)
gambarr_6 = gambarr_4
gambarr_7 = gambarr_4 
plt.imshow(gambarr)

# %%
Image_0 = cv.imread('/content/drive/MyDrive/Eula.jpg')
plt.imshow(Image_0)

# %%
Image_1=Image_0
Image_2=cv.cvtColor(Image_1,cv.COLOR_BGR2RGB)
plt.imshow(Image_2)

# %%
Image_gray=cv.imread('/content/drive/MyDrive/Eula.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(Image_gray)

# %%
plt.imshow(Image_gray, cmap='gray')

# %%
plt.imshow(Image_gray, cmap='magma')

# %%
Image_6=cv.resize(cv.cvtColor(Image_1,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(Image_6)

# %%
Image_7 = cv.flip(cv.cvtColor(Image_0,cv.COLOR_BGR2RGB),0)
fig=plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
ax.imshow(Image_7)

# %%
Blackss = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(Blackss)
#print(type(black_img))

# %%
cv.rectangle(Blackss, (0,0), (200,200), (0,255,0), 12)
cv.circle(Blackss,center=(510,150),color=(0,255,0),radius=10,thickness=12)
cv.line(Blackss,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(Blackss,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(Blackss)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili RGB
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
#1
gambarr_2 = cv.imread('/content/drive/MyDrive/PendaftaranUM/FotoGlasses.jpg',cv.IMREAD_GRAYSCALE)
#menampilkan dalam warna green-blue
plt.imshow(gambarr_2, cmap='GnBu')

# %%
cdict = {'red':  ((0.0, 0.0, 0.0),   # no red at 0
                  (0.5, 1.0, 1.0),   # all channels set to 1.0 at 0.5 to create white
                  (1.0, 0.8, 0.8)),  # set to 0.8 so its not too bright at 1

        'green': ((0.0, 0.8, 0.8),   # set to 0.8 so its not too bright at 0
                  (0.5, 1.0, 1.0),   # all channels set to 1.0 at 0.5 to create white
                  (1.0, 0.0, 0.0)),  # no green at 1

        'blue':  ((0.0, 0.0, 0.0),   # no blue at 0
                  (0.5, 1.0, 1.0),   # all channels set to 1.0 at 0.5 to create white
                  (1.0, 0.0, 0.0))   # no blue at 1
       }

# Create the colormap using the dictionary
GnRd = colorsss.LinearSegmentedColormap('GnRd', cdict)
#1
#data di ambil dari internet
#menampilkan red-green
plt.imshow(gambarr_2, cmap=GnRd)
plt.show()

# %%
#2
#menampilkan gambar yang dipotong
plt.imshow(gambarr_4[10:100,10:100])

# %%
#3
tinggi = gambarr.shape[0]
lebar = gambarr.shape[1]
plt.imshow(gambarr_4[10:100,0:lebar],cmap='Greens')

# %%
#4
randomlist=[]
for i in range(0,10):
  KonstantaRandom=random.randint(1,255)
  randomlist.append(KonstantaRandom)

for s in range(0,5):
  cv.rectangle(gambarr_4,(tinggi,randomlist[s]),(randomlist[s],lebar),(randomlist[s],randomlist[s+1],100),3)

plt.imshow(gambarr_4)

# %%
#5
gambarr_6 = cv.flip(cv.cvtColor(gambarr,cv.COLOR_BGR2RGB),0)
plt.imshow(gambarr_6)

# %%
#6
cv.rectangle(gambarr_6,(150,800),(450,1050),(randomlist[3],randomlist[4+1],100),7)
cv.circle(gambarr_6,(300,925),200,(135,269,200),7)
plt.imshow(gambarr_6)

# %%
#7
cv.rectangle(gambarr_2,(0,1400),(250,1600),(0,0,255),7)
plt.imshow(gambarr_2, cmap='Blues')

# %% [markdown]
# 1. dengan plotlib akan ada nilai sumbu x dan sumbu y pada gambar yang ditampilkan tanpa itu maka gambar akan ditampilkan dengan biasa
# 2. dengan size int berbeda maka kemampuan untuk menyimpan data juga berbeda, dan tidak sama
# 3. 3 baris tersebut digunakan untuk menunjukkan 3 channel yang mewakili RGB
# 4. jika kita ingin memanggil gambar tanpa plt.imshow, kita bisa menggunakan cv2_imshow yang akan memanggil gambar namun tanpa sumbu x dan y
# 5. untuk mengambil data gambar yang dibaca
